# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "/Users/uzu rinto/study/python/practice/Youtuber/"
df = pd.read_csv(path + 'youtuber_data.csv')

# %%
df
# Out:
#     pop_score  register_num  human_num  gender_rate  douga_num  frequency  \
# 0        9741       4860000          1          100       2164          6
# 1        8886      10900000          1          100       3238          3
# 2        7561       3810000          5          100       1471         10
# 3        7207       6720000          6          100       2577          7
# 4        6887      10300000          1          100       2661          5
# 5        6768       4660000          2          100       1950          6
# 6        6633       3250000          2            0        521          1
# 7        6605       1830000          3            0       1127         35
# 8        6415       1670000          3            0        560          4
# 9        6402       1390000          2           50        742          2
# 10       6395       2440000          3           33       2077         10
# 11       5757       1180000          1            0        492          1
# ...

# %%
columns = ["register_num","human_num","gender_rate","douga_num","frequency","saisei_max","saisei_sum","saisei_1m_ave","period","area","sub","register_sub","hyaku_achievedate"]

# %%
from sklearn.linear_model import LinearRegression

X = df[["pop_score"]]
y = df.drop(["pop_score",i], axis=1)

model = LinearRegression() 
model.fit(X,y)

print(model.score(X, y))
# Out:
# 0.18031851326689596
